# %% [markdown]
# <a href="https://colab.research.google.com/github/dstrick97/cse380-notebooks/blob/master/14_1_My_Final_Grade_Claim_for_W21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Grade Claim
# ## CSE 380 Discrete Mathematics II
# ### Winter 2021
# Daniel Strickland

# %% [markdown]
# ![DM2FinalGrade (1).png](data:image/png;base64,...)

# %% [markdown]
# ##Top 3 Evidences:
# 1. [Ladder Graph and Spanning Tree Generation](https://colab.research.google.com/github/dstrick97/cse380-notebooks/blob/master/10_2_Ponder_and_Prove_Spanning_Trees.ipynb#scrollTo=EUQlupSlp3rN&line=1&uniqifier=1)
# 2. [Clique or Anti-Clique Run Time](https://colab.research.google.com/github/dstrick97/cse380-notebooks/blob/master/11_2_Ponder_and_Prove_Verifying_Graph_Properties.ipynb#scrollTo=igq5RvLteTXT&line=1&uniqifier=1)
# 3. [Pigeonhole Proof](https://colab.research.google.com/github/dstrick97/cse380-notebooks/blob/master/12_2_Ponder_and_Prove_The_Pigeonhole_Principle.ipynb#scrollTo=30-e03fnn2kV&line=3&uniqifier=1)
